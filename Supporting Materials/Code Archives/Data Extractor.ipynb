# %%
#Must download "lxml", "html5lib", and "BeautifulSoup4" to use this database extraction

import requests
import pandas as pd

# %%
#Extract Elastic Modulus

url = 'https://www.engineeringtoolbox.com/young-modulus-d_417.html'
html = requests.get(url).content
df_list = pd.read_html(html)
df = df_list[-1]
print(df)
df.to_csv('MaterialProperties.csv')
# Out:
#                                               Material  \
#                                               Material
# 0                                         ABS plastics
# 1    A53 Seamless and Welded Standard Steel Pipe - ...
# 2    A53 Seamless and Welded Standard Steel Pipe - ...
# 3            A106 Seamless Carbon Steel Pipe - Grade A
# 4            A106 Seamless Carbon Steel Pipe - Grade B
# ..                                                 ...
# 122                                            Uranium
# 123                                           Vanadium
# 124                                       Wrought Iron
# 125                                               Wood
# 126                                               Zinc
#
#     Tensile Modulus(Young's Modulus, Modulus of Elasticity) - E -(GPa)  \
#     Tensile Modulus(Young's Modulus, Modulus of Elasticity) - E -(GPa)
# 0                                            1.4 - 3.1
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 122                                                170
# 123                                                131
# 124                                          190 - 210
# 125                                                NaN
# 126                                                 83
#
#     Ultimate Tensile Strength - σu - (MPa) Yield Strength - σy - (MPa)
#     Ultimate Tensile Strength - σu - (MPa) Yield Strength - σy - (MPa)
# 0                                       40                         NaN
# 1                                      331                         207
# 2                                      414                         241
# 3                                      330                         205
# 4                                      415                         240
# ..                                     ...                         ...
# 122                                    NaN                         NaN
# 123                                    NaN                         NaN
# 124                                    NaN                         NaN
# 125                                    NaN                         NaN
# 126                                    NaN                         NaN
#
# [127 rows x 4 columns]

# %%
#Extract price history of materials (Note: we could graph these on mat plotlib and output graph on our GUI to show user how the price of metals are going)

url = 'https://www.bls.gov/regions/mid-atlantic/data/producerpriceindexmetals_us_table.htm'
html = requests.get(url).content
df_list = pd.read_html(html)
df = df_list[-1]
print(df)
df.to_csv('MaterialCosts.csv')
# Out:
#                      Commodity and Year             Historical data  \
# 0             Metals and metal products                         NaN
# 1                                  2021                         NaN
# 2                                  2022                         NaN
# 3                        Iron and steel                         NaN
# 4                                  2021                         NaN
# ..                                  ...                         ...
# 86                                 2022                         NaN
# 87  Other plastic construction products                         NaN
# 88                                 2021                         NaN
# 89                                 2022                         NaN
# 90           Footnotes  (p) Preliminary  Footnotes  (p) Preliminary
#
#                            Jan                         Feb  \
# 0                          NaN                         NaN
# 1                        241.5                       246.6
# 2                      334.372                     330.014
# 3                          NaN                         NaN
# 4                        250.8                       260.5
# ..                         ...                         ...
# 86                     157.369                     157.369
# 87                         NaN                         NaN
# 88                       225.2                       228.1
# 89                     275.674                     281.882
# 90  Footnotes  (p) Preliminary  Footnotes  (p) Preliminary
#
#                            Mar                         Apr  \
# 0                          NaN                         NaN
# 1                        260.0                       273.4
# 2                      336.023                     341.670
# 3                          NaN                         NaN
# 4                        292.2                       321.3
# ..                         ...                         ...
# 86                     157.717                     160.159
# 87                         NaN                         NaN
# 88                       229.4                       236.9
# 89                     284.853                     291.359
# 90  Footnotes  (p) Preliminary  Footnotes  (p) Preliminary
#
#                            May                         Jun  \
# 0                          NaN                         NaN
# 1                        283.8                       294.5
# 2                      345.243                  (p)339.988
# 3                          NaN                         NaN
# 4                        332.6                       354.9
# ..                         ...                         ...
# 86                     160.931                  (p)161.212
# 87                         NaN                         NaN
# 88                       240.3                       245.8
# 89                     293.443                  (p)297.990
# 90  Footnotes  (p) Preliminary  Footnotes  (p) Preliminary
#
#                            Jul                         Aug  \
# 0                          NaN                         NaN
# 1                      305.713                     312.994
# 2                   (p)328.823                  (p)323.862
# 3                          NaN                         NaN
# 4                      382.821                     395.232
# ..                         ...                         ...
# 86                  (p)162.547                  (p)163.076
# 87                         NaN                         NaN
# 88                     252.432                     255.234
# 89                  (p)299.882                  (p)303.640
# 90  Footnotes  (p) Preliminary  Footnotes  (p) Preliminary
#
#                            Sep                         Oct  \
# 0                          NaN                         NaN
# 1                      318.335                     324.537
# 2                   (p)316.200                         NaN
# 3                          NaN                         NaN
# 4                      405.663                     417.852
# ..                         ...                         ...
# 86                  (p)162.389                         NaN
# 87                         NaN                         NaN
# 88                     257.673                     263.496
# 89                  (p)302.167                         NaN
# 90  Footnotes  (p) Preliminary  Footnotes  (p) Preliminary
#
#                            Nov                         Dec  \
# 0                          NaN                         NaN
# 1                      332.097                     331.867
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                      433.525                     433.252
# ..                         ...                         ...
# 86                         NaN                         NaN
# 87                         NaN                         NaN
# 88                     269.156                     271.278
# 89                         NaN                         NaN
# 90  Footnotes  (p) Preliminary  Footnotes  (p) Preliminary
#
#                      AnnualAvg
# 0                          NaN
# 1                      293.782
# 2                          NaN
# 3                          NaN
# 4                      356.726
# ..                         ...
# 86                         NaN
# 87                         NaN
# 88                     247.917
# 89                         NaN
# 90  Footnotes  (p) Preliminary
#
# [91 rows x 15 columns]
